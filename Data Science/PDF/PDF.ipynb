# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from Univariate import Univariate
function = Univariate
dataset = pd.read_csv("PreProcess.csv")
function.get_pdf_density(dataset['ssc_p'],60, 70)
# Out:
# Mean=67.303, standard Deviation=10.827
# The area between range(60,70):0.3449514151280293
# np.float64(0.3449514151280293)

# %%
# Here used normal and treditionl for loop method
def get_pdf_density (dataset, start, end):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.displot(dataset, kde=True, color='Green')
    pyplot.axvline(start, color='red')
    pyplot.axvline(end, color='red')
    sample = dataset
    simple_mean= sample.mean()
    simple_std= sample.std()
    print('Mean=%.3f, standard Deviation=%.3f' % (simple_mean, simple_std))
    dist = norm(simple_mean, simple_std)
    values = []
    probility=[]
    for value in range(start, end):
        values.append(value)
    for value in values:
        probility.append(dist.pdf(value))
    prob =sum(probility)
    print("The area between range({},{}):{}".format(start, end, sum(probility)))
    return prob

# %%
get_pdf_density(dataset["ssc_p"],60,70)
# Out:
# Mean=67.303, standard Deviation=10.827
# The area between range(60,70):0.3449514151280293
# np.float64(0.3449514151280293)
