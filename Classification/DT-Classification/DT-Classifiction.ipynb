# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
import pickle

dataset= pd.read_csv("Social_Network_Ads.csv")
dataset=pd.get_dummies(dataset,dtype=int, drop_first=True)
dataset=dataset.drop('User ID', axis=1)


Input=dataset[['Age', 'EstimatedSalary','Gender_Male']]
Output=dataset[['Purchased']]

dataset[['Purchased']].value_counts()

x_train,x_test,y_train,y_test = train_test_split(Input,Output, test_size=0.3, random_state=0)

params={'criterion': ['gini', 'entropy', 'log_loss'], 'splitter': ['best', 'random'], }
model = GridSearchCV(DecisionTreeClassifier(), params, refit=True, verbose=3, n_jobs=1)

model.fit(x_train, y_train)
y_pred= model.predict(x_test)

score = confusion_matrix(y_test, y_pred)
score2=classification_report(y_test, y_pred)

pickle.dump(model,open("best_model_DT.sav", "wb"))

print("Get the best model", format(model.best_params_))
print(score2)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END .....criterion=gini, splitter=best;, score=0.804 total time=   0.0s
# [CV 2/5] END .....criterion=gini, splitter=best;, score=0.821 total time=   0.0s
# [CV 3/5] END .....criterion=gini, splitter=best;, score=0.804 total time=   0.0s
# [CV 4/5] END .....criterion=gini, splitter=best;, score=0.893 total time=   0.0s
# [CV 5/5] END .....criterion=gini, splitter=best;, score=0.929 total time=   0.0s
# [CV 1/5] END ...criterion=gini, splitter=random;, score=0.857 total time=   0.0s
# [CV 2/5] END ...criterion=gini, splitter=random;, score=0.839 total time=   0.0s
# [CV 3/5] END ...criterion=gini, splitter=random;, score=0.821 total time=   0.0s
# [CV 4/5] END ...criterion=gini, splitter=random;, score=0.857 total time=   0.0s
# [CV 5/5] END ...criterion=gini, splitter=random;, score=0.893 total time=   0.0s
# [CV 1/5] END ..criterion=entropy, splitter=best;, score=0.821 total time=   0.0s
# [CV 2/5] END ..criterion=entropy, splitter=best;, score=0.857 total time=   0.0s
# [CV 3/5] END ..criterion=entropy, splitter=best;, score=0.786 total time=   0.0s
# [CV 4/5] END ..criterion=entropy, splitter=best;, score=0.893 total time=   0.0s
# [CV 5/5] END ..criterion=entropy, splitter=best;, score=0.911 total time=   0.0s
# [CV 1/5] END criterion=entropy, splitter=random;, score=0.875 total time=   0.0s
# [CV 2/5] END criterion=entropy, splitter=random;, score=0.750 total time=   0.0s
# [CV 3/5] END criterion=entropy, splitter=random;, score=0.821 total time=   0.0s
# [CV 4/5] END criterion=entropy, splitter=random;, score=0.821 total time=   0.0s
# [CV 5/5] END criterion=entropy, splitter=random;, score=0.911 total time=   0.0s
# [CV 1/5] END .criterion=log_loss, splitter=best;, score=0.821 total time=   0.0s
# [CV 2/5] END .criterion=log_loss, splitter=best;, score=0.839 total time=   0.0s
# [CV 3/5] END .criterion=log_loss, splitter=best;, score=0.804 total time=   0.0s
# [CV 4/5] END .criterion=log_loss, splitter=best;, score=0.893 total time=   0.0s
# [CV 5/5] END .criterion=log_loss, splitter=best;, score=0.911 total time=   0.0s
# [CV 1/5] END criterion=log_loss, splitter=random;, score=0.839 total time=   0.0s
# [CV 2/5] END criterion=log_loss, splitter=random;, score=0.857 total time=   0.0s
# [CV 3/5] END criterion=log_loss, splitter=random;, score=0.821 total time=   0.0s
# [CV 4/5] END criterion=log_loss, splitter=random;, score=0.750 total time=   0.0s
# [CV 5/5] END criterion=log_loss, splitter=random;, score=0.857 total time=   0.0s
# Get the best model {'criterion': 'gini', 'splitter': 'random'}
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.88        79
#            1       0.77      0.80      0.79        41
#
#     accuracy                           0.85       120
#    macro avg       0.83      0.84      0.84       120
# weighted avg       0.85      0.85      0.85       120
