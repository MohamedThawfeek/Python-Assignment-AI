# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("PreProcess.csv")

print("Number of row", dataset.shape[0])
print("Number of col", dataset.shape[1])

dataset
# Out:
# Number of row 215
# Number of col 15
#     gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# 0        M   Others   Others  Commerce   Sci&Tech     No         Mkt&HR
# 1        M  Central   Others   Science   Sci&Tech    Yes        Mkt&Fin
# 2        M  Central  Central      Arts  Comm&Mgmt     No        Mkt&Fin
# 3        M  Central  Central   Science   Sci&Tech     No         Mkt&HR
# 4        M  Central  Central  Commerce  Comm&Mgmt     No        Mkt&Fin
# ..     ...      ...      ...       ...        ...    ...            ...
# 210      M   Others   Others  Commerce  Comm&Mgmt     No        Mkt&Fin
# 211      M   Others   Others   Science   Sci&Tech     No        Mkt&Fin
# 212      M   Others   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin
# 213      F   Others   Others  Commerce  Comm&Mgmt     No         Mkt&HR
# 214      M  Central   Others   Science  Comm&Mgmt     No         Mkt&HR
#
# ...

# %%
sns.distplot(dataset["ssc_p"], kde=True, kde_kws={"color":"green"}, hist=True)
# Out:
# /var/folders/xh/qbyhzlq91t96qsm5mpr0mrqr0000gn/T/ipykernel_1242/2070965327.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["ssc_p"], kde=True, kde_kws={"color":"green"}, hist=True)
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
sns.jointplot(x="hsc_p", y="salary",data=dataset)
plt.show()

# %%
sns.jointplot(x="ssc_p", y="salary",data=dataset, kind="hex")
plt.show()

# %%
sns.jointplot(x="ssc_p", y="salary",data=dataset, kind="kde")
plt.show()

# %%
sns.pairplot(dataset, hue="gender", diag_kind="kde", kind="scatter", palette="husl")

# %%
sns.stripplot(x="ssc_b", y="ssc_p",data=dataset)
# Out:
# <Axes: xlabel='ssc_b', ylabel='ssc_p'>

# %%
sns.stripplot(x="gender", y="ssc_p",data=dataset)
# Out:
# <Axes: xlabel='gender', ylabel='ssc_p'>

# %%
sns.swarmplot(x="gender", y="ssc_p",data=dataset)

# Visualizing exact density and every individual data point.
# Out:
# <Axes: xlabel='gender', ylabel='ssc_p'>

# %%
sns.violinplot(x="ssc_b", y="ssc_p",data=dataset,
# Out:
# <Axes: xlabel='ssc_b', ylabel='ssc_p'>

# %%
sns.violinplot(x="specialisation", y="salary", data=dataset, hue="gender")
plt.ticklabel_format(style='plain', axis='y')
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# Male starting range of value is starting 48 but the female range starting value is 45 on Others
# Male starting range of value is starting 42 but the female range starting value is 44 on Central
# Male Center line starting in 68 female center line starting is 75 in here female is higher then male on Others
# Male Center line starting in 65 female center line starting is 68 in here female is higher then male on Central
# Male Q1 is 62 to 66 same on female 65 to 75 in here male is small number or percentage on matcheing on female Others
# Male Q1 is 60 to 65 same on female 62 to 68 in here male is small number or percentage on matcheing on female Central
# Male Q3 is 66 to 75 same on female 75 to 80 in here male is large number or percentage on matcheing on female Others
# Male Q3 is 65 to 75 same on female 68 to 78 in here male and female is same number of percentage Central
# Q4 Top Percentage Male is 89 percentage in female is 85 Others
# Q4 Top Percentage Male is 85 percentage in female is 87 Central
#
# Overall, female values tend to be higher than male in most ranges, especially in the starting values and median (center line) for both Others and Central categories.
#
# * In the minimum range, females start slightly higher than males in both categories (Others and Central).
# * The median (center line) is also consistently higher for females, showing better overall central performance.
# * In Q1 (lower-middle range), females again have higher values, meaning fewer low scores compared to males.
# * In Q3 (upper-middle range):
#     * For Others, females outperform males.
#     * For Central, both are almost similar.
# * In the top range (Q4):
#     * For Others, males slightly lead.
#     * For Central, females slightly lead.
#
# # Final Insight:
#
# 👉 Females generally show stronger and more consistent performance across most ranges, while males only slightly lead at the highest values in some cases (Others category).

# %%
sns.boxplot(x="ssc_b", y="ssc_p", data=dataset, hue="gender")
# Out:
# <Axes: xlabel='ssc_b', ylabel='ssc_p'>

# %%
sns.barplot(x="ssc_b", y="ssc_p", data=dataset, hue="gender")
# Out:
# <Axes: xlabel='ssc_b', ylabel='ssc_p'>

# %%
sns.countplot(x="ssc_b", data=dataset, hue="gender")
# Out:
# <Axes: xlabel='ssc_b', ylabel='count'>

# %%
sns.pointplot(x="ssc_p", y="hsc_b", data=dataset, hue="gender")
# Out:
# <Axes: xlabel='ssc_p', ylabel='hsc_b'>

# %%
sns.boxplot( data=dataset, orient="h")
# Out:
# <Axes: >
