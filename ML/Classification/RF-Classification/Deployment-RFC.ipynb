# %%
import pickle
load_model= pickle.load(open("best_model_RFC.sav", "rb"))
age=int(input("Enter your age:"))
salary=float(input("Enter your salary:"))
gender=input("Enter your Gennder:")

if (gender == "Male" or gender == "male"):
    gender=1
else :
    gender=0


result =load_model.predict([[age, salary, gender]])
result
# Out:
# Enter your age: 29
# Enter your salary: 33000
# Enter your Gennder: male
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0])
