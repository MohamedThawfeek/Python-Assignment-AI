# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
import pickle

dataset= pd.read_csv("Social_Network_Ads.csv")
dataset=pd.get_dummies(dataset,dtype=int, drop_first=True)
dataset=dataset.drop('User ID', axis=1)


Input=dataset[['Age', 'EstimatedSalary','Gender_Male']]
Output=dataset[['Purchased']]

dataset[['Purchased']].value_counts()

x_train,x_test,y_train,y_test = train_test_split(Input,Output, test_size=0.3, random_state=0)

params={}
model = GridSearchCV(MultinomialNB(), params, refit=True, verbose=3, n_jobs=1, scoring='f1_weighted')
model.fit(x_train, y_train)
y_pred= model.predict(x_test)

score = confusion_matrix(y_test, y_pred)
score2=classification_report(y_test, y_pred)

score3=roc_auc_score(y_test,model.predict_proba(x_test)[:, 1])


pickle.dump(model,open("best_model_MNB.sav", "wb"))

print("Get the best model", format(model.best_params_))
print(f'Model score:, {score3:.2f}')
print(score2)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..................................., score=0.619 total time=   0.0s
# [CV 2/5] END ..................................., score=0.503 total time=   0.0s
# [CV 3/5] END ..................................., score=0.616 total time=   0.0s
# [CV 4/5] END ..................................., score=0.610 total time=   0.0s
# [CV 5/5] END ..................................., score=0.619 total time=   0.0s
# Get the best model {}
# Model score:, 0.52
#               precision    recall  f1-score   support
#
#            0       0.71      0.86      0.78        79
#            1       0.54      0.32      0.40        41
#
#     accuracy                           0.68       120
#    macro avg       0.62      0.59      0.59       120
# weighted avg       0.65      0.68      0.65       120
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
