# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
import pickle

dataset= pd.read_csv("Social_Network_Ads.csv")
dataset=pd.get_dummies(dataset,dtype=int, drop_first=True)
dataset=dataset.drop('User ID', axis=1)


Input=dataset[['Age', 'EstimatedSalary','Gender_Male']]
Output=dataset[['Purchased']]

dataset[['Purchased']].value_counts()

x_train,x_test,y_train,y_test = train_test_split(Input,Output, test_size=0.3, random_state=0)

params={'n_neighbors': [5,10,50,100], 'weights': ['uniform', 'distance'], 'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']}
model = GridSearchCV(KNeighborsClassifier(), params, refit=True, verbose=3, n_jobs=1)
model.fit(x_train, y_train)
y_pred= model.predict(x_test)

score01 = confusion_matrix(y_test, y_pred)
score02=classification_report(y_test, y_pred)

score03=roc_auc_score(y_test,model.predict_proba(x_test)[:, 1])



pickle.dump(model,open("best_model_KNC.sav", "wb"))

print(f'Model score: {score03:.2f}')
print("Get the best model", format(model.best_params_))
print(score02)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5] END algorithm=auto, n_neighbors=5, weights=uniform;, score=0.768 total time=   0.0s
# [CV 2/5] END algorithm=auto, n_neighbors=5, weights=uniform;, score=0.732 total time=   0.0s
# [CV 3/5] END algorithm=auto, n_neighbors=5, weights=uniform;, score=0.768 total time=   0.0s
# [CV 4/5] END algorithm=auto, n_neighbors=5, weights=uniform;, score=0.839 total time=   0.0s
# [CV 5/5] END algorithm=auto, n_neighbors=5, weights=uniform;, score=0.750 total time=   0.0s
# [CV 1/5] END algorithm=auto, n_neighbors=5, weights=distance;, score=0.786 total time=   0.0s
# [CV 2/5] END algorithm=auto, n_neighbors=5, weights=distance;, score=0.750 total time=   0.0s
# [CV 3/5] END algorithm=auto, n_neighbors=5, weights=distance;, score=0.696 total time=   0.0s
# [CV 4/5] END algorithm=auto, n_neighbors=5, weights=distance;, score=0.821 total time=   0.0s
# ...
