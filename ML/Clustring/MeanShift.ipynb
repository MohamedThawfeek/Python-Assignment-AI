# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
from sklearn.cluster import MeanShift
from sklearn.metrics import silhouette_score
import seaborn as sbn

dataset= pd.read_csv("Mall_Customers.csv")

Input = dataset.iloc[:, 3:5].values
array_list=[]


model = MeanShift(bandwidth=22).fit(Input)
cluster_centers = model.cluster_centers_
labels = model.labels_
n_clusters_ = len(set(labels))
print(n_clusters_)

model= MeanShift(bandwidth=22)
y_predict=model.fit_predict(Input)

score = silhouette_score(Input, y_predict)
print(score)



supervice_table= pd.DataFrame(dataset)
supervice_table["Cluster_group"]= y_predict

supervice_table




cluster_chart= sbn.lmplot(data=supervice_table, x=supervice_table.columns[3], y=supervice_table.columns[4],
                          hue=supervice_table.columns[5], fit_reg=False, legend=True, legend_out=True)
# Out:
# 5
# 0.5488706129170663
# /opt/anaconda3/lib/python3.13/site-packages/seaborn/regression.py:598: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
