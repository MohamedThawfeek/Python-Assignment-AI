# %%
import pandas as pd
import pickle
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

dataset=pd.read_csv("insurance_pre.csv")
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)
dataset
Input=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
Output=dataset[['charges']]
x_train, x_test, y_train, y_test = train_test_split(Input, Output, test_size=1/3, random_state=0)
sc=StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

scy=StandardScaler()
y_train = scy.fit_transform(y_train)
y_test = scy.transform(y_test)


preinput=sc.transform([[33,27.900, 0, 1, 1]])

load_model = pickle.load(open("best_model.sav", "rb"))

result = load_model.predict(preinput)

PreOutput = scy.inverse_transform([result])
PreOutput
# Out:
# /Volumes/2TB-ext/opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Volumes/2TB-ext/opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([[1.74908459e+08]])
